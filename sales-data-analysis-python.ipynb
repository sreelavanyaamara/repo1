# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#    Order Date Region         Category Sub-Category  Sales  Profit
# 0  2023-01-05  South        Furniture       Chairs   2500     400
# 1  2023-02-12   East       Technology       Phones   3200     650
# 2  2023-03-18   West  Office Supplies      Binders   1500     200
# 3  2023-04-22  North        Furniture       Tables   2800     350
# 4  2023-05-10  South       Technology      Laptops   4500     900

# %%
df.head()
# Out:
#    Order Date Region         Category Sub-Category  Sales  Profit
# 0  2023-01-05  South        Furniture       Chairs   2500     400
# 1  2023-02-12   East       Technology       Phones   3200     650
# 2  2023-03-18   West  Office Supplies      Binders   1500     200
# 3  2023-04-22  North        Furniture       Tables   2800     350
# 4  2023-05-10  South       Technology      Laptops   4500     900

# %%
df.shape
# Out:
# (12, 6)

# %%
df.columns
# Out:
# Index(['Order Date', 'Region', 'Category', 'Sub-Category', 'Sales', 'Profit'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    12 non-null     object
#  1   Region        12 non-null     object
#  2   Category      12 non-null     object
#  3   Sub-Category  12 non-null     object
#  4   Sales         12 non-null     int64
#  5   Profit        12 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 708.0+ bytes

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    Order Date Region         Category Sub-Category  Sales  Profit
# 0  2023-01-05  South        Furniture       Chairs   2500     400
# 1  2023-02-12   East       Technology       Phones   3200     650
# 2  2023-03-18   West  Office Supplies      Binders   1500     200
# 3  2023-04-22  North        Furniture       Tables   2800     350
# 4  2023-05-10  South       Technology      Laptops   4500     900

# %%
df.isnull().sum()
# Out:
# Order Date      0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Profit          0
# dtype: int64

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['Order Date', 'Region', 'Category', 'Sub-Category', 'Sales', 'Profit'], dtype='object')

# %%
df = df.rename(columns={
    'Quantity_Ordered': 'Quantity',
    'Unit_Price': 'Price'
})

# %%
df.columns.tolist()
# Out:
# ['Order Date', 'Region', 'Category', 'Sub-Category', 'Sales', 'Profit']

# %%
df.head()
# Out:
#    Order Date Region         Category Sub-Category  Sales  Profit
# 0  2023-01-05  South        Furniture       Chairs   2500     400
# 1  2023-02-12   East       Technology       Phones   3200     650
# 2  2023-03-18   West  Office Supplies      Binders   1500     200
# 3  2023-04-22  North        Furniture       Tables   2800     350
# 4  2023-05-10  South       Technology      Laptops   4500     900

# %%
df['Sales'].sum()
# Out:
# np.int64(31700)

# %%
category_sales = df.groupby('Category')['Sales'].sum()
category_sales
# Out:
# Category
# Furniture          10900
# Office Supplies     5900
# Technology         14900
# Name: Sales, dtype: int64

# %%
region_sales = df.groupby('Region')['Sales'].sum()
region_sales
# Out:
# Region
# East     7000
# North    6400
# South    8800
# West     9500
# Name: Sales, dtype: int64

# %%
df['Profit'].sum()
# Out:
# np.int64(5190)

# %%
category_profit = df.groupby('Category')['Profit'].sum()
category_profit
# Out:
# Category
# Furniture          1550
# Office Supplies     840
# Technology         2800
# Name: Profit, dtype: int64

# %%
import matplotlib.pyplot as plt

category_sales.plot(kind='bar')
plt.title("Category Wise Sales")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
category_profit.plot(kind='bar')
plt.title("Category Wise Profit")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.show()

# %%
df.to_csv("cleaned_sales_data.csv", index=False)
